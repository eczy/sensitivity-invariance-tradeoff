# %%
from adversarial_invariance.invariance_generator import InvarianceGenerator
import numpy as np
import matplotlib.pyplot as plt

# %%
from keras.datasets import mnist

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# idxs = np.load("../invariance_examples/indexs.npy")
idxs = np.arange(100)
assert len(idxs) == 100
test_xs = X_test[idxs]
test_ys = Y_test[idxs]

# %%
generator = InvarianceGenerator()
generator.fit(X_train, Y_train)
foo = generator.best_neighbor(X_test[0], Y_test[0])

# %%
fig, ax = plt.subplots(1, 10, figsize=(10, 10))
ax[0].imshow(X_test[0])
for i, nn in enumerate(foo[0]):
    ax[i + 1].imshow(nn)

# %%
plt.imshow(generator.invariance_attack(X_train[0], y_train[0]), cmap='gray')

# %%
for i, (nn, y_nn, _) in enumerate(foo):
