# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torchvision.datasets import CIFAR10

# %%
dataset = CIFAR10("./data", train=True, download=True)
# Out:
# Files already downloaded and verified

# %%
plt.imshow(dataset[1][0])

# %%
tns = torch.load("data/inv_attacks_cifar_train_0.pt")

# %%
tns.shape
# Out:
# torch.Size([32, 32, 3])

# %%
plt.imshow(tns.numpy().astype(int))

# %%
n_samples = 10
fig, axarr = plt.subplots(n_images, 2, figsize=(2, n_images))

for i in range(n_samples):
    tns = torch.load(f"data/inv_attacks_cifar_train_{i}.pt")

    axarr[i][0].imshow(dataset.data[i])
    axarr[i][1].imshow(tns.int().numpy())

plt.show()
